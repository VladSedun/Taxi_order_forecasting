# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Привет!👋</b>
#
# Уточни, пожалуйста, как я могу к тебе обращаться? В недрах Практикума не нашел твоего имени.
#
# Меня зовут Кирилл Васильев, я буду ревьюером твоего проекта. Я предлагаю общаться на «ты», но если привычнее на «вы», просто скажи об этом!
#
# Я буду оставлять комментарии в твоем проекте. Пожалуйста, не удаляй их, они могут быть полезны в случае повторной проверки.
#
# Свои комментарии я буду обозначать <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным. Здесь же я могу давать советы и предложения.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# <br/>
# <div class="alert alert-info">
# Рекомендую для твоих комментариев использовать синий или любой другой цветной фон. Я постараюсь ничего не пропустить, но если комментарии будут выделены, то это мне очень поможет!
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.

# %% [markdown]
# <div class="alert alert-info">
# Влад
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Привет, Влад
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Импортируем-библиотеки:" data-toc-modified-id="Импортируем-библиотеки:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импортируем библиотеки:</a></span></li><li><span><a href="#Запись-csv-файла-в-переменную:" data-toc-modified-id="Запись-csv-файла-в-переменную:-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Запись csv-файла в переменную:</a></span></li><li><span><a href="#Выведем-на-экран-первые-10-строк-датафрейма-taxi--и-общую-информацию-по-нему:" data-toc-modified-id="Выведем-на-экран-первые-10-строк-датафрейма-taxi--и-общую-информацию-по-нему:-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Выведем на экран первые 10 строк датафрейма taxi  и общую информацию по нему:</a></span></li><li><span><a href="#Проверим-индекс-на-монотонность" data-toc-modified-id="Проверим-индекс-на-монотонность-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проверим индекс на монотонность</a></span></li><li><span><a href="#Ресемплируем-данные-по-часу" data-toc-modified-id="Ресемплируем-данные-по-часу-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Ресемплируем данные по часу</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Построим-график-количества-вызовов-такси:" data-toc-modified-id="Построим-график-количества-вызовов-такси:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Построим график количества вызовов такси:</a></span></li><li><span><a href="#Построение-графика-количества-вызовов-такси-при-помощи-метода-скользящего-среднего:" data-toc-modified-id="Построение-графика-количества-вызовов-такси-при-помощи-метода-скользящего-среднего:-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Построение графика количества вызовов такси при помощи метода скользящего среднего:</a></span></li><li><span><a href="#Построение-графика-трендовой-составляющей-временного-ряда:" data-toc-modified-id="Построение-графика-трендовой-составляющей-временного-ряда:-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Построение графика трендовой составляющей временного ряда:</a></span></li><li><span><a href="#Построение-графика-сезонной-составляющей--временного-ряда-с-ресемплированием-в-1-час:" data-toc-modified-id="Построение-графика-сезонной-составляющей--временного-ряда-с-ресемплированием-в-1-час:-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Построение графика сезонной составляющей  временного ряда с ресемплированием в 1 час:</a></span></li><li><span><a href="#Построение-графика-сезонной-составляющей(срез-за-последние-два-дня-датафрейма)-временного-ряда-с-ресемплированием-в-1-час:" data-toc-modified-id="Построение-графика-сезонной-составляющей(срез-за-последние-два-дня-датафрейма)-временного-ряда-с-ресемплированием-в-1-час:-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Построение графика сезонной составляющей(срез за последние два дня датафрейма) временного ряда с ресемплированием в 1 час:</a></span></li><li><span><a href="#Построение-графика-сезонной-составляющей--временного-ряда-с-ресемплированием-в-1-день:" data-toc-modified-id="Построение-графика-сезонной-составляющей--временного-ряда-с-ресемплированием-в-1-день:-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Построение графика сезонной составляющей  временного ряда с ресемплированием в 1 день:</a></span></li><li><span><a href="#Построение-графика-сезонной-составляющей(срез-за-последние-4--недели-датафрейма)-временного-ряда-с-ресемплированием-в-1-день:" data-toc-modified-id="Построение-графика-сезонной-составляющей(срез-за-последние-4--недели-датафрейма)-временного-ряда-с-ресемплированием-в-1-день:-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Построение графика сезонной составляющей(срез за последние 4  недели датафрейма) временного ряда с ресемплированием в 1 день:</a></span></li><li><span><a href="#Построение-графика-остатков--временного-ряда:" data-toc-modified-id="Построение-графика-остатков--временного-ряда:-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Построение графика остатков  временного ряда:</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Создаем-кастомный-scorer-для-RMSE:" data-toc-modified-id="Создаем-кастомный-scorer-для-RMSE:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создаем кастомный scorer для RMSE:</a></span></li><li><span><a href="#Подготовка-признаков" data-toc-modified-id="Подготовка-признаков-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Подготовка признаков</a></span></li><li><span><a href="#Формирование-тестовой-и-тренировочной-выборок:" data-toc-modified-id="Формирование-тестовой-и-тренировочной-выборок:-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Формирование тестовой и тренировочной выборок:</a></span></li><li><span><a href="#Расчет-параметров-для--модели--RidgeRegression:" data-toc-modified-id="Расчет-параметров-для--модели--RidgeRegression:-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Расчет параметров для  модели  RidgeRegression:</a></span><ul class="toc-item"><li><span><a href="#Словарь-с-параметрами--модели-RidgeRegression:" data-toc-modified-id="Словарь-с-параметрами--модели-RidgeRegression:-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Словарь с параметрами  модели RidgeRegression:</a></span></li><li><span><a href="#Создание-и-обучение-модели-OptunaSearchCV:" data-toc-modified-id="Создание-и-обучение-модели-OptunaSearchCV:-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Создание и обучение модели OptunaSearchCV:</a></span></li></ul></li><li><span><a href="#Расчет-параметров-для--модели--CatBoostRegressor---:" data-toc-modified-id="Расчет-параметров-для--модели--CatBoostRegressor---:-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Расчет параметров для  модели  CatBoostRegressor   :</a></span><ul class="toc-item"><li><span><a href="#Словарь-с-параметрами--модели-CatBoostRegressor:" data-toc-modified-id="Словарь-с-параметрами--модели-CatBoostRegressor:-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Словарь с параметрами  модели CatBoostRegressor:</a></span></li><li><span><a href="#Создание-и-обучение-модели-OptunaSearchCV:" data-toc-modified-id="Создание-и-обучение-модели-OptunaSearchCV:-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Создание и обучение модели OptunaSearchCV:</a></span></li></ul></li><li><span><a href="#Расчет-параметров-для--модели--LGBMRegressor----:" data-toc-modified-id="Расчет-параметров-для--модели--LGBMRegressor----:-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Расчет параметров для  модели  LGBMRegressor    :</a></span><ul class="toc-item"><li><span><a href="#Словарь-с-параметрами--модели-LGBMRegressor:" data-toc-modified-id="Словарь-с-параметрами--модели-LGBMRegressor:-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Словарь с параметрами  модели LGBMRegressor:</a></span></li><li><span><a href="#Создание-и-обучение-модели-OptunaSearchCV:" data-toc-modified-id="Создание-и-обучение-модели-OptunaSearchCV:-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>Создание и обучение модели OptunaSearchCV:</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-моделей" data-toc-modified-id="Анализ-моделей-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ моделей</a></span><ul class="toc-item"><li><span><a href="#Выделение-лучшей-модели-RidgeRegression:" data-toc-modified-id="Выделение-лучшей-модели-RidgeRegression:-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Выделение лучшей модели RidgeRegression:</a></span></li><li><span><a href="#Выделение-лучшей-модели-CatBoostRegressor:" data-toc-modified-id="Выделение-лучшей-модели-CatBoostRegressor:-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Выделение лучшей модели CatBoostRegressor:</a></span></li><li><span><a href="#Выделение-лучшей-модели--LGBMRegressor-:" data-toc-modified-id="Выделение-лучшей-модели--LGBMRegressor-:-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выделение лучшей модели  LGBMRegressor :</a></span></li><li><span><a href="#Формирование-итоговой-таблицы-для-сравнения-моделей:" data-toc-modified-id="Формирование-итоговой-таблицы-для-сравнения-моделей:-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Формирование итоговой таблицы для сравнения моделей:</a></span></li><li><span><a href="#Расчет-метрики--и-анализ-лучшей-модели-на-тестовых-данных" data-toc-modified-id="Расчет-метрики--и-анализ-лучшей-модели-на-тестовых-данных-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Расчет метрики  и анализ лучшей модели на тестовых данных</a></span></li><li><span><a href="#Проверим-модели-на-адекватность-смещением:" data-toc-modified-id="Проверим-модели-на-адекватность-смещением:-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Проверим модели на адекватность смещением:</a></span></li><li><span><a href="#Визуализация-результатов" data-toc-modified-id="Визуализация-результатов-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Визуализация результатов</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><span><a href="#На--этапе-&quot;Загрузка-данных&quot;-было-сделано:" data-toc-modified-id="На--этапе-&quot;Загрузка-данных&quot;-было-сделано:-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>На  этапе "Загрузка данных" было сделано:</a></span></li><li><span><a href="#На--этапе-&quot;Анализ-данных&quot;-была-описана-и-визуализирована-общая-информация-о-временном-ряде-датафрейма-и--сделаны-следующие-выводы:" data-toc-modified-id="На--этапе-&quot;Анализ-данных&quot;-была-описана-и-визуализирована-общая-информация-о-временном-ряде-датафрейма-и--сделаны-следующие-выводы:-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>На  этапе "Анализ данных" была описана и визуализирована общая информация о временном ряде датафрейма и  сделаны следующие выводы:</a></span></li><li><span><a href="#На-этапе-&quot;Обучение-моделей-&quot;-была-проделана-работа:" data-toc-modified-id="На-этапе-&quot;Обучение-моделей-&quot;-была-проделана-работа:-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>На этапе "Обучение моделей " была проделана работа:</a></span></li><li><span><a href="#На-этапе-&quot;Анализ-моделей-&quot;-была-проделана-работа:" data-toc-modified-id="На-этапе-&quot;Анализ-моделей-&quot;-была-проделана-работа:-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>На этапе "Анализ моделей " была проделана работа:</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Проект "Прогнозирование заказов такси"

# %% [markdown]
# **Описание проекта:**
#
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час.
#
#
#
# **Цель проекта:**
#
# - Нужно построить модель для  прогнозирования количество заказов такси на следующий час;
#
# - Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# **Описание данных:**
#
# **taxi.csv**
# Таблица, которая содержит данные о количество заказов:
#
# - datetime — дата и время в хронологии заказов(с интервалом в 10 минут);
#
# - num_orders — количество заказов (целевой признак).
#
#
# **Ход работы:**
#
# - Загрузка данных:загрузка и изучение общей информации из предоставленных датасетов.
#
# - Анализ данных:изучение основных параметров признаков,их распределения.
#
# - Обучение моделей:формирование и использование пайплайнов для нахождения лучшей модели МО.
#
# - Анализ моделей:сравнение лучших моделей по видам и их анализ.
#
# **Общий вывод:** резюмирование полученных результатов,формулировка ключевых выводов и рекомендаций.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# ### Импортируем библиотеки:

# %%
# !pip install matplotlib==3.5.0 -q
# !pip install optuna -q 
# !pip install optuna.integration -q

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично, что используешь тихую загрузку.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import  StandardScaler, MinMaxScaler,RobustScaler


from sklearn.metrics import make_scorer, mean_squared_error
from optuna import distributions
from optuna.integration import OptunaSearchCV

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer


from sklearn.linear_model import LinearRegression,Ridge
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.seasonal import seasonal_decompose

from statsmodels.graphics import tsaplots


import time

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Все ок, но возомжно стоит уточнить по тому, какие импорты могут быть лишними. Например, в нашей задаче, кажется, масштабирование не потребуется.

# %% [markdown]
# ### Запись csv-файла в переменную:

# %%
pd.set_option('display.max_colwidth', 999)
taxi = pd.read_csv("/datasets/taxi.csv",parse_dates = ['datetime'],index_col = ['datetime'])

# %% [markdown]
# ### Выведем на экран первые 10 строк датафрейма taxi  и общую информацию по нему:

# %%
display(taxi.head(10))
taxi.info()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# 2018-03-01 00:50:00          21
# 2018-03-01 01:00:00           7
# 2018-03-01 01:10:00           5
# 2018-03-01 01:20:00          17
# 2018-03-01 01:30:00          12
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %% [markdown]
# Вывод:как видно из результатов,в датафрейме отсутствуют пропуски,столбцы имеют корректный тип данных,наименования столбцов соответствуют стандарту PEP 8.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Описание задачи есть, библиотеки загружены. Данные получены верно, даты обработаны, мы их переместили в индекс. Полет нормальный
# </div>

# %% [markdown]
# ### Проверим индекс на монотонность

# %%
print(taxi.index.is_monotonic)
# Out:
# True

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично, что делаешь проверку на монотонность.
# </div>

# %% [markdown]
# ### Ресемплируем данные по часу

# %%
taxi_2 = taxi.copy()#Создадим копию исходного датафрейма для анализа другого уровня ресемплирования

taxi = taxi.resample('1H').sum()
taxi_2 = taxi_2.resample('1D').sum()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Ресемплирование провели верно. Отлично, что используем суммирование. Такой вариант интуитивно понятен и удобен, ну и соответствует нашему заданию.
# </div>

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Построим график количества вызовов такси:

# %%
taxi.plot(figsize=(16, 7))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Вывод:как видно из результатов,данные имеют относительно постоянные колебания значений в течении дня,но несмотря на это видно,что график плавно идет вверх,что скорее всего говорит о наличии тренда.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Здесь определенно можно говорить о наличии тренда с возрастанием количества заказов. Можно также предположить наличие квадритичного тренда в августе.
#
# Скорее всего, это часть годовой сезонности (сезон отпусков, повышенная нагрузка на аэропорты и, как следствие, такси рядом), однако пока у нас данные всего за пять месяцев, для нас это будет тренд на увеличение с квадратичным завершением.
# </div>

# %% [markdown]
# ### Построение графика количества вызовов такси при помощи метода скользящего среднего:

# %%
taxi['num_orders'].shift(1).rolling(24).mean().plot(figsize=(16, 7))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Вывод:для построения графика было выбрано окно в 24 часа(суточный размер,так как наши данный семплированы до 1 часа).Ввиду того,что скользящее окно сглаживает флуктуации остатков и по сути является примитивным способом выделение трендовой составляющей ,можно сказать,что тренд имеется и он плавно увеличивается с начала марта до конца августа.Ввиду того,что данные иллюстрируют кол-во вызовов такси в аэропорт можно предположить,что тренд характеризует рост увеличения кол-во полетов людей на отдых в теплое время года(и как результат,увеличение вызовов такси).Исходя из того,что так происходит каждый год(основываясь на эмпирическом опыте),в пределах имеющихся данных,данное увеличение можно отнести к тренду,но в масштабе нескольких лет это может являться сезонной составляющей.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично, наши мысли сошлись.
# </div>

# %% [markdown]
# ### Построение графика трендовой составляющей временного ряда:

# %%
decomposed = seasonal_decompose(taxi) 

plt.figure(figsize=(13, 15))
plt.subplot(311)
# Чтобы график корректно отобразился, указываем его
# оси ax, равными plt.gca() (англ. get current axis,
# получить текущие оси)
decomposed.trend.plot(ax=plt.gca())

plt.tight_layout()

# %% [markdown]
# Вывод:как видно из результатов,график трендовой составляющей полностью копируют график количества вызовов такси при помощи метода скользящего среднего.

# %% [markdown]
# ### Построение графика сезонной составляющей  временного ряда с ресемплированием в 1 час:

# %%
plt.figure(figsize=(13, 15))
plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca()) 
plt.title('Seasonality')
plt.tight_layout()

# %% [markdown]
# Вывод:различить что-то на графике сложно,но тем не менее,по форме видно,что данные имеют явную переодичность.Построим еще один график,взяв срез за последние два дня датафрейма.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Здесь можем изучить суточную сезонность, если возьмем сезонность за несколько дней.
#
#
#
# Важно также изучить недельную сезонность. Удобнее всего ее увидеть, если сделать дополнительное ресемплирование (сохраняем в другую переменную, так как дальше в проекте будем работать с ресемплированием по часам и важно его не потерять) по дням. При ресемплировании по часам недельная сезонность уходит в тренд декомпозиции.

# %% [markdown]
# <div class="alert alert-info">
#
# - Добавлены пукнты с анализам сезонной составляющей датафрейма с ресемплирование по уровню в 1 день  (пункты 2.6 и 2.7)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍
# </div>

# %% [markdown]
# ### Построение графика сезонной составляющей(срез за последние два дня датафрейма) временного ряда с ресемплированием в 1 час:

# %%
plt.figure(figsize=(13, 15))
plt.subplot(312)
decomposed.seasonal['2018-08-30':'2018-08-31'].plot(ax=plt.gca()) 
plt.title('Seasonality')
plt.tight_layout()

# %% [markdown]
# Вывод:как видно из результатов,в вечернее  и ночное время(до 24:00) спрос на такси резко растет,в период с 24:00 до 01:00 спрос резко падает,затем имеется небольшой рост,за которым следует резкий спад (до 06:00 утра).После утренного времени в течении дня до вечера спрос на такси изменяется скачкообразно,но сохраняя суточную тенденцию к повышению.Ввиду того,что данная информация характеризуется кол-вом вызовов такси в аэропорт можно сделать предположение,что все пики и спады привязаны к расписанию прилетов-отлетов самолетов в аэропортах.

# %% [markdown]
# ### Построение графика сезонной составляющей  временного ряда с ресемплированием в 1 день:

# %%
decomposed_2 = seasonal_decompose(taxi_2)
plt.figure(figsize=(13, 15))
plt.subplot(312)
decomposed_2.seasonal.plot(ax=plt.gca()) 
plt.title('Seasonality')
plt.tight_layout()

# %% [markdown]
# Вывод:различить что-то на графике сложно,но тем не менее,по форме видно,что данные имеют явную переодичность.Построим еще один график,взяв срез за последние 4 недели датафрейма.

# %% [markdown]
# ### Построение графика сезонной составляющей(срез за последние 4  недели датафрейма) временного ряда с ресемплированием в 1 день:

# %%
plt.figure(figsize=(13, 15))
plt.subplot(312)
decomposed_2.seasonal["2018-08-06":"2018-08-31"].plot(ax=plt.gca()) 
plt.title('Seasonality')
plt.tight_layout()

# %% [markdown]
# Вывод:как видно из результатов,с понедельника на вторник идет резкий спад,достигая своего недельного минимума.После этого,со вторника по пятницу идет постепенное увеличение,достигая пика в ночь с четверга на пятницу.Затем следует спад до ночи с субботы на воскресенье.В воскресенье наблюдается резкий подъем,за которым (в понедельник)следуте падение и процесс повторяется сначала.Можно предположить,что подъем в  дни со вторника по четверг связан с тем,что в это дни люди улетают на отдых,в пятницу и субботу если не улетели,то остаются дома,а в воскресенье массово возвращаются домой.Имеется достаточно сильная недельная составляющая.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Верно, отлично
# </div>

# %% [markdown]
# ### Построение графика остатков  временного ряда:

# %%
plt.figure(figsize=(13, 15))
plt.subplot(312)
decomposed.resid.plot(ax=plt.gca()) 
plt.title('Residuals')
plt.tight_layout()

# %% [markdown]
# Вывод:как видно из результатов,остатки имеют относительно постоянную дисперсию значений.Отдельно стоит заметить большие выбросы в августе месяце.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Всё верно.
#
# Здесь стоит отметить сразу вот что. Если если «остатков» к концу графика больше, значит в тестовую выборку попадет чуть больше данных, которые сложно объяснить и на которых модели будет сложнее предсказывать. Поэтому относительно большая (по сравнению с другими задачами машинного обучения в нашем курсе) разница между метриками при обучении и исследовании, и между тестовой выборкой, необязательно будет объясняться только переобучением модели.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Смотри, выше замечательно по анализу ряда, но было бы отлично все кратко резюмировать в промежуточном выводе. Это как раз можно будет использовать и как аргументацию к созданию новых фичей.

# %% [markdown]
# В ходе анализа данных были построены графики составляющих временного ряда и сделаны следующие выводы:
#
# 1)Общий график количества вызовов такси:
#
# - Данные имеют относительно постоянные колебания значений в течении дня,но несмотря на это видно,что график плавно идет вверх,что скорее всего говорит о наличии тренда.
#
# 2)График количества вызовов такси при помощи метода скользящего среднего:
#
# - Для построения графика было выбрано окно в 24 часа(суточный размер,так как наши данный семплированы до 1 часа).Ввиду того,что скользящее окно сглаживает флуктуации остатков и по сути является примитивным способом выделение трендовой составляющей ,можно сказать,что тренд имеется и он плавно увеличивается с начала марта до конца августа.Ввиду того,что данные иллюстрируют кол-во вызовов такси в аэропорт можно предположить,что тренд характеризует рост увеличения кол-во полетов людей на отдых в теплое время года(и как результат,увеличение вызовов такси).Исходя из того,что так происходит каждый год(основываясь на эмпирическом опыте),в пределах имеющихся данных,данное увеличение можно отнести к тренду,но в масштабе нескольких лет это может являться сезонной составляющей.
#
# 3)График трендовой составляющей временного ряда:
#
# - График трендовой составляющей полностью копируют график количества вызовов такси при помощи метода скользящего среднего.
#
# 4)График сезонной составляющей(срез за последние два дня датафрейма) временного ряда с ресемплированием в 1 час:
#
# - В вечернее  и ночное время(до 24:00) спрос на такси резко растет,в период с 24:00 до 01:00 спрос резко падает,затем имеется небольшой рост,за которым следует резкий спад (до 06:00 утра).После утренного времени в течении дня до вечера спрос на такси изменяется скачкообразно,но сохраняя суточную тенденцию к повышению.Ввиду того,что данная информация характеризуется кол-вом вызовов такси в аэропорт можно сделать предположение,что все пики и спады привязаны к расписанию прилетов-отлетов самолетов в аэропортах.
#
# 5)График сезонной составляющей(срез за последние 4  недели датафрейма) временного ряда с ресемплированием в 1 день:
#
# - С понедельника на вторник идет резкий спад,достигая своего недельного минимума.После этого,со вторника по пятницу идет постепенное увеличение,достигая пика в ночь с четверга на пятницу.Затем следует спад до ночи с субботы на воскресенье.В воскресенье наблюдается резкий подъем,за которым (в понедельник)следуте падение и процесс повторяется сначала.Можно предположить,что подъем в  дни со вторника по четверг связан с тем,что в это дни люди улетают на отдых,в пятницу и субботу если не улетели,то остаются дома,а в воскресенье массово возвращаются домой.Имеется достаточно сильная недельная составляющая.
#
# 6)График остатков  временного ряда:
#
# - Остатки имеют относительно постоянную дисперсию значений.Отдельно стоит заметить  большие выбросы в августе месяце.

# %% [markdown]
# <div class="alert alert-info">
# - Добавлен  вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍
# </div>

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# ### Создаем кастомный scorer для RMSE:

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))
rmse_scorer = make_scorer(rmse, greater_is_better=False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 `greater_is_better=False` - все так.
#
# Альтернативно в кросс-валидации можно было бы использовать встроенный RMSE. Он будет называться neg_root_mean_squared_error

# %% [markdown]
# ### Подготовка признаков

# %% [markdown]
# Создадим переменную для кросс-валидации временных рядов:

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Верно, не перемешиваем.

# %% [markdown]
# Определим при помощи  метода автокорреляции наиболее коррелирующие лаги:

# %%
fig = tsaplots.plot_acf(taxi['num_orders'],lags= 180)
fig.set_size_inches(17.5, 6)
plt.ylim(-.1, 1.1)
plt.show()

# %% [markdown]
# Создадим признаки для горизонта прогнозирования в один шаг

# %%
lags = [1, 2, 23, 24, 25,167, 168, 169]
taxi['day'] = taxi.index.day
taxi['day_of_week'] = taxi.index.dayofweek
taxi['hour'] = taxi.index.hour
for lag in lags:
    taxi['lag_{}'.format(lag)] = taxi['num_orders'].shift(lag)
taxi['rolling_mean'] = taxi['num_orders'].shift(1).rolling(24).mean()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Все ли признаки нам пригодятся? У нас данные за какой период? Можем ли «поймать» годовую сезонность? Важен ли месяц?
#
# Наши календарные признаки подчеркивают сезонность. Относительно сезонности признаки идут на один уровень ниже. Если у нас суточная сезонность, то логично создавать признак часа (час одного дня похож на тот же час другого), если недельная - день недели.
#
# И напротив, выше изучили данные и увидели, что суточная сезонность достаточно сильная. Здесь нам будет важно выделить признак часа.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# - Удален признак месяца;
#
# - Добавлен признак часа.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><S> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
#
# Один из самых важных признаков в задаче временных рядов - это так называемые «лаги», то есть, значения предыдущих периодов наблюдения. Мы помним, что модель не считает по столбцам таблицы, она считает и подбирает веса к строкам нашего датасета. Соответственно, если мы хотим, чтобы модель предсказывала следующее значение, опираясь на предыдущие, нужно, чтобы она эти предыдущие значения увидела (по горизонтали нашего датасета). Нам важно создать новые колонки с отстающими значениями. Особенно полезны будут те лаги, которые имеют высокую корреляцию с таргетом. Логично, что высокая корреляция будет при выраженной сезонности. Если у нас посуточная сезонность, то каждый час одних суток будет немного похож по динамике заказов на тот же час предыдущих суток (например, к 17:00 количество заказов увеличивается, к 00:00 еще, а к 6:00 падает до минимума, и так каждый день. Значит, нам понадобится 24-й лаг, который будет отражать суточную сезонность. Если есть недельная сезонность, то по этой же причине нам будет очень важен 168-й лаг.
#
# Значимость лагов можно посмотреть по автокорреляции. Функция показывает, как признак коррелирует с предыдущими. Область синей заливки обозначает порог статистической значимости (если значение внутри, корреляция уже не заслуживает доверия. Статзначимость вычисляется по тесту Стьюдента).
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# - Добавлены лаги суточной и недельной сезонности и их ближайшие значения;
#
# - Построен график автокорреляции.
#
# </div>

# %% [markdown]
# ###  Формирование тестовой и тренировочной выборок:

# %%
train, test = train_test_split(taxi, shuffle=False, test_size=0.1)
train = train.dropna()

X_train = train.drop(columns='num_orders')
y_train = train['num_orders']
X_test = test.drop(columns='num_orders')
y_test = test['num_orders']

print(X_train.shape)
print(X_test.shape)
# Out:
# (3804, 14)
# (442, 14)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Верно, ничего не перемешиваем.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><S> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# В случае с временными рядами нужно предсказывать следующее значение предыдущим в константной модели:
#
#
# `pred_previous = target_test.shift()
# pred_previous.iloc[0] = target_train.iloc[-1]`
#
# Предсказание средним не подойдет по двум причинам:
#
# 1. мы должны для константной модели выбирать лучшую стратегию по качеству из имеющихся.
# 2. Здесь мы для каждого из значений предсказываем среднее по тестовой выборке, но строго говоря мы не должны использовать для предсказания данные из будущего. При построении дамми- модели в случае с временными рядами иногда можно использовать константную модель (если она эффективнее), но тогда предсказывать нужно на тренировочной выбоке.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# - Заменено на проверку адекватности смещением(перемещено в конец проекта).
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Отлично
# </div>

# %% [markdown]
# ###  Расчет параметров для  модели  RidgeRegression:

# %% [markdown]
# Ввиду малого разброса в масштабах значений входных признаков,масштабировать данные не будем.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Еще раз подсвечу этот момент:
#
# У нас все признаки примерно в одном масштабе, здесь можно обойтись без масштабирования, хотя хуже оно не делает.

# %% [markdown]
# <div class="alert alert-info">
#
# - Убрано для всех моделей.
#
# </div>

# %% [markdown]
# #### Словарь с параметрами  модели RidgeRegression:

# %%
  # словарь для модели RidgeRegression()
param_opt_r = {   
        'alpha': distributions.IntDistribution(0, 10)}

# %% [markdown]
# #### Создание и обучение модели OptunaSearchCV:

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# А что и зачем здесь делаем? Качество на тренировочной нам не дает примерно никакой полезной информации, качество на тестовой выводить до выбора лучшей модели мы не имеем права, если хотим получить объективную оценку модели.
#
# ***
#
# Предсказывать на тренировочной выборке неэффективно. Не видим реального результата, просто смотрим, как модель выучила конкретные данные и ничего не знаем о ее обобщающей способности.
#
# Предсказивать же на тестовой выборке до тестирования также не стоит. Тестирование - просто проверка моделей. В шаге исследования моделей мы должны смотреть на качество иначе.
#
# Если выделяем две выборки, то рекомендую здесь использовать исключительно кросс-валидацию для определения качества модели.

# %% [markdown]
# <div class="alert alert-info">
#
# Забыл это удалить(была проблема с Optuna и промежуточно проверял данные)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Понял, так и подумал.
# </div>

# %% [markdown]
# Сформируем таблицу результатов моделей по значениям метрики:

# %%
opt_r = OptunaSearchCV(
        Ridge(),
        param_opt_r,
        cv=tscv,
        scoring= rmse_scorer,
        n_trials=4,
        error_score='raise',n_jobs=-1)

opt_r.fit(X_train, y_train)
# выводим результат моделирования
print('Лучшая модель и её параметры:\n\n', opt_r.best_estimator_) 
print ('Метрика лучшей модели на тренировочной выборке:', opt_r.best_score_*-1)#Ввиду того,что при установке значения greater_is_better=False в методе scrore метрика будет выбирать самую маленькое значение и умножать на -1,компенсируем этот момент умноженим на -1.
# Out:
# /tmp/ipykernel_218/625073284.py:1: ExperimentalWarning: OptunaSearchCV is experimental (supported from v0.17.0). The interface can change in the future.
#   opt_r = OptunaSearchCV(
# [I 2025-07-31 20:02:10,664] A new study created in memory with name: no-name-7d299d62-e18b-4f80-bee3-c96a22984cdc
# [I 2025-07-31 20:02:11,073] Trial 1 finished with value: -22.920722531660374 and parameters: {'alpha': 6}. Best is trial 1 with value: -22.920722531660374.
# [I 2025-07-31 20:02:11,078] Trial 0 finished with value: -22.92072169173964 and parameters: {'alpha': 8}. Best is trial 0 with value: -22.92072169173964.
# [I 2025-07-31 20:02:11,174] Trial 2 finished with value: -22.920717495321924 and parameters: {'alpha': 18}. Best is trial 2 with value: -22.920717495321924.
# [I 2025-07-31 20:02:11,263] Trial 3 finished with value: -22.92072169173964 and parameters: {'alpha': 8}. Best is trial 2 with value: -22.920717495321924.
# Лучшая модель и её параметры:
#
#  Ridge(alpha=18)
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# А зачем используешь `n_trials=10` ? В норме этот параметр отвечает за то, сколько вариантов сочетания гиперпараметров мы возьмем для подбора оптимальных. Если у нас модель без гиперпарамеров, то `n_trials=10` будет означать, что мы просто обучим одно и то же 10 раз подряд.
#
# В рандомайздсече у нас типа рандомный выбор гиперпараметров из заданной сетки (на самом деле чуть сложнее тоже), а в оптуне типа интеллектуальный, но я бы предположил, что при некотором относительно небольшом задаваемом количестве гиперпараметров и нам выгоднее просмотреть все, просто уточнив более детально успешные диапазоны значений, и модельке будет сложно оптимизироваться на небольшом поле сочетаний параметров. То есть, я бы и в нашем случае в оптуне скорее не использовал n_trials, даже при условии, что в общем он, конечно, попробует как-то сработать и что-то оптимизировать.
#
# ***
#
# `Метрика лучшей модели на тренировочной выборке` - кажется, в теории спринта «Обучение с учителем» была такая формулировка в тренажере и пример для пайплайна. Это не совсем точная формулировка, все-таки здесь смотрим качество не на тренировочной выборке, а на кросс-валидации, то есть на некоторой выборке, на которой модель не обучалась.
#
# В случае с временным рядом в каждом сплите валидационные (ну или в контексте кросс-валидации можно назвать их тестовыми) индексы должны быть позже по времени, чем обучающие, поэтому перетасовка обычным способом неуместна. Как раз TimeSeriesSplit решает эту проблему.
#
# Схематично работу можно представить вот так:\
# </font>
# ![image.png](https://scikit-learn.org/stable/_images/sphx_glr_plot_cv_indices_013.png)

# %% [markdown]
# <div class="alert alert-info">
#
# - Во всех оптунах  количество траев уменьшено до 3-4.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍  Здесь по реализации все верно.

# %%
display(opt_r.trials_dataframe().sort_values('value',ascending=False).head(10))
# Out:
#    number      value             datetime_start          datetime_complete  \
# 2       2 -22.920717 2025-07-31 20:02:10.671794 2025-07-31 20:02:11.174412
# 0       0 -22.920722 2025-07-31 20:02:10.666903 2025-07-31 20:02:11.078386
# 3       3 -22.920722 2025-07-31 20:02:10.684856 2025-07-31 20:02:11.263252
# 1       1 -22.920723 2025-07-31 20:02:10.668779 2025-07-31 20:02:11.073154
#
#                 duration  params_alpha  user_attrs_mean_fit_time  \
# 2 0 days 00:00:00.502618            18                  0.094458
# 0 0 days 00:00:00.411483             8                  0.074848
# 3 0 days 00:00:00.578396             8                  0.092155
# 1 0 days 00:00:00.404375             6                  0.060830
#
#    user_attrs_mean_score_time  user_attrs_mean_test_score  \
# 2                    0.004894                  -22.920717
# 0                    0.006239                  -22.920722
# 3                    0.021591                  -22.920722
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍  Обрати внимание, отсутствие масштабирования картину не меняет.
#
# n_trials дают идентичные результаты. Это абсолютно ожидаемое и прогнозируемое поведение. Отлично, что пробуешь разные варианты, но в финальном решении я бы оставил здесь модель без масштабирования.
#
# Прирост качества здесь основной будет при грамотном создании фичей для модели. По идее все фичи у нас будут производными от одного - количества заказов. Поэтому связи между фичами будут достаточно простыми, линейные модели будут хорошо их схватывать «из коробки».

# %% [markdown]
# ###  Расчет параметров для  модели  CatBoostRegressor   :

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Твой комментарий выше корректен в целом по алгоритму, но конкретно в нашей задаче никакая модель не требует кодирования и масштабирования.
#
# Линейная модель будет очень слабо воспринимать, например, прямое кодирование календарных признаков. Можно попробовать закодировать порядковым кодированием (синус, косинус), но и это не даст статистически значимого прироста. Поэтому можно просто ничего не кодировать, но вложиться в создание большого количества отстающих значений − лагов, которые отразят все сезонности и тренд.
#
# Остальные модели, как пишешь, в любом случае не будут нуждаться в кодировании и масштабировании.
#
# ***
#
# Просто для уточнения, порядковое кодирование может выглядеть в простом варианте вот так:
#
#
# `df['sin_hour'] = np.sin(2*np.pi*df.index.hour/24)
# df['cos_hour'] = np.cos(2*np.pi*df.index.hour/24)`
#
# Применяется для циклических признаков во временных рядах и для кодирования позиции слов в предложениях в языковых моделях, если используем алгоритмы, которые не учитывают позицию (например, трансфореры не учитывают, а lstm учитывают).

# %% [markdown]
# #### Словарь с параметрами  модели CatBoostRegressor:

# %%
# словарь для модели CatBoostRegressor()
param_opt_cbr = {   
        'learning_rate': distributions.CategoricalDistribution([1e-5, 3e-5, 1e-4, 3e-4, 1e-3, 3e-3, 1e-2, 3e-2, 1e-1, 0.3, 1.0]),
        'depth': distributions.CategoricalDistribution([1,2])}

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Еще момент. Подбор learning_rate от 0.2 до 0.8 - это крайне неэффективно. Оптимальный параметр скорости обучения у нас может быть в очень широком диапазоне, обычно если его подбираем руками, то задаем в логарифмической шкале. Давать максимально узенькое окно невыгодно - мы скорее всего будем далеко от оптимума и пессимизируем таким образом качество модели. Заранее очень сложно прикинуть, какие у нас будут веса внутри модели, а lr будет «плясать» от весов (это некоторый коэффициент, на который умножаем производную при градиентном спуске, обычно чтобы она не перескочила нужный нам оптимум или наоборот, чтобы не застряла в локальном).
#
# `'models__learning_rate': [1e-5, 3e-5, 1e-4, 3e-4, 1e-3, 3e-3, 1e-2, 3e-2, 1e-1, 0.3, 1.0]`
#
# Ну или через распределение:
#
# `'models__learning_rate': distributions.LogUniformDistribution(1e-5, 1.0)`
#
# Если не ошибаюсь, в кэтбусте из коробки есть неплохой быстрый «определятор» хорошего learning_rate, если ничего не задавать, он сработает вполне оптимально.

# %% [markdown]
# <div class="alert alert-info">
#
# - Выполнены рекомендации.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍
# </div>

# %% [markdown]
# #### Создание и обучение модели OptunaSearchCV:

# %%
opt_cbr = OptunaSearchCV(
        CatBoostRegressor(allow_writing_files=False, verbose=0 ),
        param_opt_cbr,
        cv=tscv,
        scoring= rmse_scorer,
        n_trials=,
        error_score='raise',n_jobs=1)

opt_cbr.fit(X_train, y_train)
# выводим результат моделирования
print('Лучшая модель и её параметры:\n\n', opt_cbr.best_estimator_) 
print ('Метрика лучшей модели на тренировочной выборке:', opt_cbr.best_score_*-1)#Ввиду того,что при установке значения greater_is_better=False в методе scrore метрика будет выбирать самую маленькое значение и умножать на -1,компенсируем этот момент умноженим на -1.
# Out:
# /tmp/ipykernel_218/1951441783.py:1: ExperimentalWarning: OptunaSearchCV is experimental (supported from v0.17.0). The interface can change in the future.
#   opt_cbr = OptunaSearchCV(
# [I 2025-07-31 20:04:44,493] A new study created in memory with name: no-name-afabb114-f7f3-4340-b523-956a915b4a8a
# [I 2025-07-31 20:04:46,922] Trial 0 finished with value: -24.9355162196028 and parameters: {'learning_rate': 0.3, 'depth': 2}. Best is trial 0 with value: -24.9355162196028.
# [I 2025-07-31 20:04:48,490] Trial 1 finished with value: -37.80071939934206 and parameters: {'learning_rate': 0.0003, 'depth': 1}. Best is trial 0 with value: -24.9355162196028.
# [I 2025-07-31 20:04:50,961] Trial 2 finished with value: -40.08340829182662 and parameters: {'learning_rate': 3e-05, 'depth': 2}. Best is trial 0 with value: -24.9355162196028.
# ...

# %% [markdown]
# Сформируем таблицу результатов моделей по значениям метрики:

# %%
display(opt_cbr.trials_dataframe().sort_values('value',ascending=False).head(10))
# Out:
#    number      value             datetime_start          datetime_complete  \
# 0       0 -24.935516 2025-07-31 20:04:44.494678 2025-07-31 20:04:46.922336
# 1       1 -37.800719 2025-07-31 20:04:46.923378 2025-07-31 20:04:48.490748
# 2       2 -40.083408 2025-07-31 20:04:48.491788 2025-07-31 20:04:50.961728
# 3       3 -40.371596 2025-07-31 20:04:50.962760 2025-07-31 20:04:53.395436
#
#                 duration  params_depth  params_learning_rate  \
# 0 0 days 00:00:02.427658             2               0.30000
# 1 0 days 00:00:01.567370             1               0.00030
# 2 0 days 00:00:02.469940             2               0.00003
# 3 0 days 00:00:02.432676             2               0.00001
#
#    user_attrs_mean_fit_time  user_attrs_mean_score_time  \
# 0                  0.481725                    0.002740
# 1                  0.310120                    0.002377
# 2                  0.490245                    0.002657
# ...

# %% [markdown]
# ###  Расчет параметров для  модели  LGBMRegressor    :

# %% [markdown]
# #### Словарь с параметрами  модели LGBMRegressor:

# %%
# словарь для модели LGBMRegressor()
param_opt_lgbmr = { 
        'n_estimators': distributions.CategoricalDistribution([10,15,20,50,100]),
        'learning_rate': distributions.CategoricalDistribution([0.5,0.1,0.2]),
        'num_leaves': distributions.CategoricalDistribution([50,100,150])
}

# %% [markdown]
# #### Создание и обучение модели OptunaSearchCV:

# %%
opt_lgbmr = OptunaSearchCV(
        LGBMRegressor(),
        param_opt_lgbmr,
        cv=tscv,
        scoring= rmse_scorer,
        n_trials=3,
        error_score='raise',n_jobs=-1)

opt_lgbmr.fit(X_train, y_train)
# выводим результат моделирования
print('Лучшая модель и её параметры:\n\n', opt_lgbmr.best_estimator_) 
print ('Метрика лучшей модели на тренировочной выборке:', opt_lgbmr.best_score_*-1)#Ввиду того,что при установке значения greater_is_better=False в методе scrore метрика будет выбирать самую маленькое значение и умножать на -1,компенсируем этот момент умноженим на -1.
# Out:
# /tmp/ipykernel_218/2105738056.py:1: ExperimentalWarning: OptunaSearchCV is experimental (supported from v0.17.0). The interface can change in the future.
#   opt_lgbmr = OptunaSearchCV(
# [I 2025-07-31 20:10:26,797] A new study created in memory with name: no-name-571eecf5-5b9f-4bda-9797-243d0d8a79a3
# [I 2025-07-31 20:10:33,868] Trial 1 finished with value: -24.916326200036927 and parameters: {'n_estimators': 10, 'learning_rate': 0.5, 'num_leaves': 100}. Best is trial 1 with value: -24.916326200036927.
# [I 2025-07-31 20:10:45,663] Trial 0 finished with value: -26.0840518388275 and parameters: {'n_estimators': 50, 'learning_rate': 0.5, 'num_leaves': 50}. Best is trial 1 with value: -24.916326200036927.
# [I 2025-07-31 20:11:03,473] Trial 2 finished with value: -24.243384477661333 and parameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 100}. Best is trial 2 with value: -24.243384477661333.
# Лучшая модель и её параметры:
#
# ...

# %% [markdown]
# Сформируем таблицу результатов моделей по значениям метрики:

# %%
display(opt_lgbmr.trials_dataframe().sort_values('value',ascending=False).head(10))
# Out:
#    number      value             datetime_start          datetime_complete  \
# 2       2 -24.243384 2025-07-31 20:10:26.804720 2025-07-31 20:11:03.472967
# 1       1 -24.916326 2025-07-31 20:10:26.802876 2025-07-31 20:10:33.867972
# 0       0 -26.084052 2025-07-31 20:10:26.799172 2025-07-31 20:10:45.663132
#
#                 duration  params_learning_rate  params_n_estimators  \
# 2 0 days 00:00:36.668247                   0.2                  100
# 1 0 days 00:00:07.065096                   0.5                   10
# 0 0 days 00:00:18.863960                   0.5                   50
#
#    params_num_leaves  user_attrs_mean_fit_time  user_attrs_mean_score_time  \
# 2                100                  7.311269                    0.020085
# 1                100                  1.406670                    0.003929
# 0                 50                  3.721622                    0.049665
#
#    ...  user_attrs_split0_test_score  user_attrs_split1_test_score  \
# ...

# %% [markdown]
# ## Анализ моделей

# %% [markdown]
# ### Выделение лучшей модели RidgeRegression:

# %%
df_r = pd.DataFrame(opt_r.cv_results_).sort_values('mean_test_score',ascending = False).head(1)

# %% [markdown]
# ### Выделение лучшей модели CatBoostRegressor:

# %%
df_cbr = pd.DataFrame(opt_cbr.cv_results_).sort_values('mean_test_score',ascending = False).head(1)

# %% [markdown]
# ### Выделение лучшей модели  LGBMRegressor :

# %%
df_lgbm = pd.DataFrame(opt_lgbmr.cv_results_).sort_values('mean_test_score',ascending = False).head(1)

# %% [markdown]
# ### Формирование итоговой таблицы для сравнения моделей:

# %% [markdown]
# Сформируем таблицу со значениями лучших моделей:

# %%
data = pd.concat([df_r, df_cbr, df_lgbm], axis=0)

data.index = ['RidgeRegression', 'CatBoostRegressor', 'LGBMRegressor']
data['mean_test_score'] = data['mean_test_score']*-1
data= data.drop(['split0_test_score','split1_test_score','split2_test_score','split3_test_score','split4_test_score'],axis = 1)

# %%
display(data)
# Out:
#                    mean_fit_time  std_fit_time  mean_score_time  \
# RidgeRegression         0.094458      0.054985         0.004894
# CatBoostRegressor       0.481725      0.116874         0.002740
# LGBMRegressor           7.311269      1.274603         0.020085
#
#                    std_score_time  mean_test_score  std_test_score
# RidgeRegression          0.002011        22.920717        3.397112
# CatBoostRegressor        0.000323        24.935516        3.196435
# LGBMRegressor            0.031081        24.243384        3.416037

# %% [markdown]
# Вывод:как видно из результатов,лучшей и по времени , и по ключевой метрике оказалась модель RidgeRegression.Выберем ее.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Про подсчет времени - заметь, у тебя в таблице выше среди параметров уже есть время обучения и время предсказания.
#
# Ты выводишь с помощью `opt_lgbmr.trials_dataframe()`
#
# Обычно в кросс-валидации выводим через cv_results_ и тоже оборачиваем в датафрейм.

# %% [markdown]
# <div class="alert alert-info">
#
# - Выполнены рекомендации.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 По выбору модели - ок. Единственное, подсвечу еще раз, если подадим больше лагов, будем ждать хорошего качества от линейной модели. При доработке приглядись к ней.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Хорошо, что заметил)
#
# Смотри, дело все в том же - кросс-валидация это не предсказание на тренировочной выборке. Это предсказание на некотором куске данных в конце сплитованной выборки, который в конкретном раунде обучения не участвовал. В слове кросс-валидация основное «валидация», а валидационная часть у нас всегда в обучении не участвует. Здесь исключений нет.
#
# Выше же ты некорректно замеряешь качество на всей тренировочной выборке, частью на этих данных мы обучали модель. Метрика показывает не качество модели, а то, как она запомнила конкретные строки датасета. Ну нам это неинтересно, оно для использования модели не пригодится.

# %% [markdown]
# <div class="alert alert-info">
#
# - Обучение моделей на тренировочных данных убрано(проведено сравнение характеристик при кросс-валидации).
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍
# </div>

# %% [markdown]
# ###  Расчет метрики  и анализ лучшей модели на тестовых данных

# %% [markdown]
# Сформируем и сохраним предсказания на тестовой выборке по параметрам лучшей  модели :

# %%
estimator_r = opt_r.best_estimator_
estimator_r.fit(X_train, y_train)
preds_r = estimator_r.predict(X_test)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Вот при тестировании мы можем дополнительно обучить модель  на всех данных, особенно, чтобы попали данные, которые будут более актуальными.

# %% [markdown]
# Расчитаем метрику RMSE для тестовых данных по параметрам лучшей модели:

# %%
print("RMSE_best_model:", mean_squared_error(y_test,preds_r,squared=False))
# Out:
# RMSE_best_model: 35.145245582101396

# %% [markdown]
# Вывод:как видно из результатов,значение метрики меньше 48,а значит модель соответствует требованиям ТЗ.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Отличный результат
# </div>

# %% [markdown]
# ### Проверим модели на адекватность смещением:

# %%
pred_previous = y_test.shift()
pred_previous.iloc[0] = y_train.iloc[-1]
print("RMSE_dummy_model:", mean_squared_error(pred_previous, y_test,squared=False))
# Out:
# RMSE_dummy_model: 58.856486242815066

# %% [markdown]
# Вывод:как видно из результатов,значения RMSE лучшей модели более чем в 1.5 раза меньше значения Dummy модели,а значит модель Ridge хорошо справляется и есть смысл в ее использовании.

# %% [markdown]
# ### Визуализация результатов

# %% [markdown]
# Построим график с истинными значениями и предсказанными:

# %%
data = pd.concat([y_test, pd.DataFrame(data = preds_r,index = y_test.index,columns= ['num_orders_pred'])], axis=1)

# %%
data.plot(figsize=(16, 7))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Вывод:как видно из результатов, в целом график предсказанных значений соответствует графику истинных значений.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Ух, сильно переобучились, судя по всему. Пока недобрали до нужного качества, хотя модель будет адекватнее предсказания предыдущим значением.
#
# Кстати, выше не указал, нам полезнее всего делать замер константной модели (предсказанием предыдущим значением) на тестовой выборке. Нам же интересно, насколько при несмещенной оценке качества модель работает лучше наивной.

# %% [markdown]
# <div class="alert alert-info">
#
# - Метрика соответствует требованиям ТЗ.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Ага
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Я бы здесь перенес в конец проверку на адекватность. Еще очень полезно построить линейный график для тестовой выборки и наложить на него график наших предсказаний. Так увидим, где модель чаще ошибается.
#
# Предположу, что нам (то есть бизнесу) не так уж и интересно предсказывать для каждого периода количество заказов, сколько интересно прогнозировать пиковые нагрузки (чтобы скорректировать стоимость поездки и привлечь водителей, когда это требуется). Нужно бы уточнить, хорошо ли наша модель угадывает пиковые нагрузки?
#
# Также обязательно нужно проговорить, откуда взялось такое катастрофическое падение качества модели.
#
# (Я бы, честно говоря, здесь вообще бы чуть подобрезал августовские данные, пожертвовав самым ценным и актуальным периодом, чтобы взамен получить более адекватную оценку именно способности модели к прогнозированию ряда.
#
# С другой стороны, с учетом использования августа мы получаем представление о том, как модель себя ведет в условиях появления неопределенности и шума - изменения тренда, некоторой деформации сезонностей, увеличения остатков итд.)

# %% [markdown]
# ## Общий вывод
#
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час.
#
#
#
# **Цель проекта:**
#
# - Нужно построить модель для  прогнозирования количество заказов такси на следующий час;
#
# - Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
#
#
# ### На  этапе "Загрузка данных" было сделано:
#
# 1) Загружены данные из csv-файла taxi.csv и создан датафреймы **taxi** с данными о количестве заказов такси в аэропорт :
#
# - datetime — дата и время в хронологии заказов(с интервалом в 10 минут);
#
# - num_orders — количество заказов (целевой признак).
#
# Произведен осмотр данных датафрейма.Все столбцы имели корректные типы данных  и не имели пропусков и дубликатов.
#
# 2) Индексы проверены на монотонность;
#
# 3) Данные ресемплированы по часу и суткам.
#
#
# ### На  этапе "Анализ данных" была описана и визуализирована общая информация о временном ряде датафрейма и  сделаны следующие выводы:
#
#
# 1)Общий график количества вызовов такси:
#
# - Данные имеют относительно постоянные колебания значений в течении дня,но несмотря на это видно,что график плавно идет вверх,что скорее всего говорит о наличии тренда.
#
# 2)График количества вызовов такси при помощи метода скользящего среднего:
#
# - Для построения графика было выбрано окно в 24 часа(суточный размер,так как наши данный семплированы до 1 часа).Ввиду того,что скользящее окно сглаживает флуктуации остатков и по сути является примитивным способом выделение трендовой составляющей ,можно сказать,что тренд имеется и он плавно увеличивается с начала марта до конца августа.Ввиду того,что данные иллюстрируют кол-во вызовов такси в аэропорт можно предположить,что тренд характеризует рост увеличения кол-во полетов людей на отдых в теплое время года(и как результат,увеличение вызовов такси).Исходя из того,что так происходит каждый год(основываясь на эмпирическом опыте),в пределах имеющихся данных,данное увеличение можно отнести к тренду,но в масштабе нескольких лет это может являться сезонной составляющей.
#
# 3)График трендовой составляющей временного ряда:
#
# - График трендовой составляющей полностью копируют график количества вызовов такси при помощи метода скользящего среднего.
#
# 4)График сезонной составляющей(срез за последние два дня датафрейма) временного ряда с ресемплированием в 1 час:
#
# - В вечернее  и ночное время(до 24:00) спрос на такси резко растет,в период с 24:00 до 01:00 спрос резко падает,затем имеется небольшой рост,за которым следует резкий спад (до 06:00 утра).После утренного времени в течении дня до вечера спрос на такси изменяется скачкообразно,но сохраняя суточную тенденцию к повышению.Ввиду того,что данная информация характеризуется кол-вом вызовов такси в аэропорт можно сделать предположение,что все пики и спады привязаны к расписанию прилетов-отлетов самолетов в аэропортах.
#
# 5)График сезонной составляющей(срез за последние 4  недели датафрейма) временного ряда с ресемплированием в 1 день:
#
# - С понедельника на вторник идет резкий спад,достигая своего недельного минимума.После этого,со вторника по пятницу идет постепенное увеличение,достигая пика в ночь с четверга на пятницу.Затем следует спад до ночи с субботы на воскресенье.В воскресенье наблюдается резкий подъем,за которым (в понедельник)следуте падение и процесс повторяется сначала.Можно предположить,что подъем в  дни со вторника по четверг связан с тем,что в это дни люди улетают на отдых,в пятницу и субботу если не улетели,то остаются дома,а в воскресенье массово возвращаются домой.Имеется достаточно сильная недельная составляющая.
#
# 6)График остатков  временного ряда:
#
# - Остатки имеют относительно постоянную дисперсию значений.Отдельно стоит заметить  большие выбросы в августе месяце.
#
#
#
#
# ### На этапе "Обучение моделей " была проделана работа:
#
#
# 1)Сформирована функция для расчета метрики RMSE;
#
# 2)Была произведена подготовка признаков и проделаны следующие шаги:
#
# - Создана переменная для кросс-валидации временных рядов;
#
# - При помощи  метода автокорреляции определины наиболее коррелирующие лаги;
#
# - Созданы признаки для горизонта прогнозирования в один шаг.
#
# 3)Cформированы  тестовая и тренировочная выбороки;
#
# 4)Был произведен расчет параметров  для  модели  RidgeRegression и проделаны следующие шаги:
#
# - Сформирован словарь с параметрами  модели RidgeRegression;
#
# - Создана и обучена модель OptunaSearchCV для поиска лучших гиперпараметров.
#
# 5)Был произведен расчет параметров  для  модели  CatBoostRegressor и проделаны следующие шаги:
#
# - Сформирован словарь с параметрами  модели CatBoostRegressor;
#
# - Создана и обучена модель OptunaSearchCV для поиска лучших гиперпараметров.
#
# 6)Был произведен расчет параметров  для  модели  LGBMRegressor и проделаны следующие шаги:
#
# - Сформирован словарь с параметрами  модели LGBMRegressor;
#
# - Создана и обучена модель OptunaSearchCV для поиска лучших гиперпараметров.
#
#
# ### На этапе "Анализ моделей " была проделана работа:
#
# 1)Выделена лучшая модель RidgeRegression;
#
# 2)Выделена лучшая модель CatBoostRegressor;
#
# 3)Выделена лучшая модель LGBMRegressor;
#
# 4)Сформирована итоговая таблица для сравнения моделей,по результатам которой лучшей была выбрана модель RidgeRegression;
#
# 5)Произведен расчет метрики  и анализ лучшей модели на тестовых данных( значение метрики меньше 48,а значит модель соответствует требованиям ТЗ);
#
# 6)Модель проверена на адекватность смещением (значения RMSE лучшей модели более чем в 1.5 раза меньше значения Dummy модели,а значит модель Ridge хорошо справляется и есть смысл в ее использовании);
#
# 7)Произведена визуализация результатов (в целом график предсказанных значений соответствует графику истинных значений).

# %% [markdown]
# <div class="alert alert-info">
# - Добавлен итоговый вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Общий вывод может быть короче, но более насыщенный важной для нашего потенциального читателя информацией.
#
# ***
#
# Наши комментарии в проектах можно условно разделить на описательные и объясняющие.
#
# Обычно и те, и другие можно сделать достаточно краткими - чуть менее краткими, чем на слайдах презентации. Лучше писать комментарии, которые будут выделять главное, привлекать внимание к важному, а также объяснять данные. Условно, в комментарии отвечаем на вопрос «что здесь самое важное и почему важно именно это».
#
# В промежуточных выводах также достаточно будет верхнеуровнево перечислить главные итоги и дать краткую аргументацию решений.
#
# В общем выводе мы отвечаем на вопросы целей и задач проекта, описываем результаты и модели, даем рекомендации по дальнейшему улучшению и исследованию.
#
# Всегда смотрим с позиции читателя проекта - будет ли текстовая информация ему помогать в чтении проекта или будет уже излишней. Держим в уме, что наш предполагаемый читатель уже просмотрел наши решения и пересказывть полностью решения ему не нужно.
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проверке**
#
# Вдумчивая работа, интересно проверять, видна логика решений, есть, что улучшить. Специфику задачи временных рядов в каждом случае учитываешь верно (ну кроме константной модели).
#
# Основное: я бы подвинул фокус внимания с моделирования на исследование и создание фичей. Все признаки у нас идут от количества заказов, взаимосвязи между признаками будут для моделей достаточно простыми. Моделирование − просто дело техники. Здесь важно только не путать, зачем мы создаем выборки в DS.
#
# А вот от того, какие фичи мы создадим будет зависеть то, как модельки усвоят заложенные в данных тренд и сезонности.
#
# * Важно изучить сезонности и на основе анализа ряда создать только нужные нам признаки.
# * Нужно увеличить количество лагов (минимум до 24, но я бы взял и все 168. Либо можно по автокорреляции сразу создать только значимые).
# * Уточняемся по выборкам. На тренировочной выборке качество считать не надо примерно никогда, если только не хочешь убедиться, что модель вообще обучается. В нашем случае вроде бы очевидно, что модельки что-то подбирают.
# * Константную модель логичнее посмотреть для тестовой выборки. Предсказывать средним не можем − заглядываем в будущее (на проде такой фокус, увы, пока не повторим).
# * Жду общий вывод.
#
# Задавай вопросы по проекту.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Комментарий ко второй проверке**
#
# Спасибо за доработку. 🤝
#
# Критичных комментариев нет.
#
# Если что-то пропустил, интересны дополнительные материалы по теме проекта или остались вопросы, напиши в телеграм @kriill
#
# Желаю удачи в дальнейшей учебе!
#
# </div>
